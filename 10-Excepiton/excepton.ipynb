# %%
## Exception handling 
try:
    a = b
except:
    print("variable has not assigned ")
# Out:
# variable has not assigned

# %%
a = b
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 a = b
#
# NameError: name 'b' is not defined

# %%
try:
    a = b
except NameError as ne:
    print(ne)
# Out:
# name 'b' is not defined

# %%
## Zero division error
res = 3/0
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[6], line 2
#       1 ## Zero division error
# ----> 2 res = 3/0
#
# ZeroDivisionError: division by zero

# %%
try:
    res = 2/0
except ZeroDivisionError as ex:
    print(ex)
# Out:
# division by zero

# %%
try:
    res = 2/1
    a=b
except ZeroDivisionError as ex:
    print(ex)
    print("denominator should greater than 0")
except Exception as e:
    print(e)
    print("main exception got here")
# Out:
# name 'b' is not defined
# main exception got here

# %%
try:
    num = int(input("Enter the number"))
    res = 10/num
except ValueError:
    print("this is not number")
except ZeroDivisionError:
    print("number should greater then 0")
except Exception as e:
    print(e)

# %%
try:
    num = int(input("Enter the number : "))
    res = 10/num
except ValueError:
    print("this is not number")
except ZeroDivisionError:
    print("number should greater than zero")
except Exception as e:
    print(e)
else:
    print(f"the result is {res}")
# Out:
# number should greater than zero

# %%
## try, excerpt, else and finally
try:
    num = int(input("Enter the number : "))
    res = 10/num
except ValueError:
    print("this is not number")
except ZeroDivisionError:
    print("number should greater than zero")
except Exception as e:
    print(e)
else:
    print(f"the result is {res}")
finally:
    print('Execution compelte')
# Out:
# number should greater than zero
# Execution compelte

# %%
## file handling andExcepiton handling

try:
    file=open('example1.txt','r')
    a=b
    content =file.read()
    print(content)
except FileNotFoundError as e:
    print(e)

except Exception as e:
    print(e)
finally:
    if 'file' in locals() or file.closed():
        file.close()
        print('file close')
# Out:
# name 'b' is not defined
# file close
