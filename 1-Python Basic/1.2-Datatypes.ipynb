# %%
# integer example
age = 20
print(type(age))
# Out:
# <class 'int'>

# %%
# floating point data type example

height = 6.1
print(height)
print(type(height))
# Out:
# 6.1
# <class 'float'>

# %%
# sritng data type example

name = "Asim"
print(name)
print(type(name))
# Out:
# Asim
# <class 'str'>

# %%
# boolean data type example

is_boolean = True
print(type(is_boolean))
# Out:
# <class 'bool'>

# %%
a = 10
b = 10

type(a==b)
# Out:
# bool

# %%
# common error
# result = "Hello" + 5 # this will give error

# %%
result = "Hello" + str(5)
print(result) # this will execute
# Out:
# Hello5
