# %%
## list is a collection of the item & list is the mutable

list = [1,4,54,54, "Asim"]

# %%
# list index start from the 0 up to n 

print(list[0])
print(list[1])
print(list[2])
print(list[3])
print(list[4])
# Out:
# 1
# 4
# 54
# 54
# Asim

# %%
# list travers using the for loop 

for i in list:
    print(i)
# Out:
# 1
# 4
# 54
# 54
# Asim

# %%
# list
