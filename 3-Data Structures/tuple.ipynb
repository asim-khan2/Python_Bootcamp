# %% [markdown]
# #### 📌 Tuple in Python
#
# ###### A tuple is a collection data type in Python that:
#
# ###### ✅ Stores multiple items
# ###### ✅ Is ordered (items have fixed positions)
# ###### ❌ Is immutable (you cannot change, add, or remove items after creation)
# ###### ✅ Can store different data types (int, float, string, etc.)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# index() method 
t = (1,2,4,4,6)
print(type(t))
print(t)
# Out:
# <class 'tuple'>
# (1, 2, 4, 4, 6)

# %%
tup1 = ('Asim','Najim',3,3,6)
tup2 = (2,5,7,9,4)
tup3 = ('a','c','b')
tup4 = (2.4, True,-5, 1+2j)
print(type(tup1))
print(type(tup2))
print(type(tup3))
print(type(tup4))
# Out:
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>

# %%
# empty tuple tupe = ()
tupe = ()
print(tupe)
# Out:
# ()

# %%
'''To write a tuple containing a single value 
you have to include a comma, even though there is only one value '''

tup = (5) # assign the integer value in the variable tup
tup1 = (5,) # this is the  right
print(tup)
print(tup1)
print(type(tup))
print(type(tup1))
# Out:
# 5
# (5,)
# <class 'int'>
# <class 'tuple'>

# %% [markdown]
# Accessint values in tupel

# %%
tup = ('Asim','Khan',3,46,7)
tup1 = ('a','b','c','d')
print("tup[0] : ", tup[0])
print("tup1[0:len(tup1)] : ",tup1[0:4])
# Out:
# tup[0] :  Asim
# tup1[0:len(tup1)] :  ('a', 'b', 'c', 'd')

# %% [markdown]
# Updating tupel

# %%
# Tuple are immutable
tup1 = (2,4,5,'Asim')
tup2 = (2,4,4,"Khan")
# following action is not valid in tuple
# tup[2] = "Khan" 

tup3 = tup1 + tup2
print(tup3)
# Out:
# (2, 4, 5, 'Asim', 2, 4, 4, 'Khan')

# %% [markdown]
# ### Delete Tuple Elements
# Removing individual tuple elements is not possible. There is, of course, nothing wrong with putting together another tuple with the undesired elements discarded.
#
# To explicitly remove an entire tuple, just use the del statement. For example

# %%
tup = ('Asim','Khan',1,24,6,4)
print(tup)
del tup
print('After the deleting tup ')
print(tup) # it will give error
# Out:
# ('Asim', 'Khan', 1, 24, 6, 4)
# After the deleting tup
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[19], line 5
#       3 del tup
#       4 print('After the deleting tup ')
# ----> 5 print(tup) # it will give error
#
# NameError: name 'tup' is not defined

# %% [markdown]
# ### Delete Tuple Elements
# Removing individual tuple elements is not possible. There is, of course, nothing wrong with putting together another tuple with the undesired elements discarded.
#
# To explicitly remove an entire tuple, just use the del statement. For example

# %%
print((1,3,4) + (3,2,4,7))
print(('hi',) * 3)
tup = (2,4,6,75,4)
print(75 in tup)
print( 3 in (3,6,7,5,6))
# Out:
# (1, 3, 4, 3, 2, 4, 7)
# ('hi', 'hi', 'hi')
# True
# True

# %%
print ('abc', -4.24e93, 18+6.6j, 'xyz');
x, y = 1, 2;
print ("Value of x , y : ", x,y);
# Out:
# abc -4.24e+93 (18+6.6j) xyz
# Value of x , y :  1 2

# %%
a =5; print(a); a=6 ;print("Hello"); print(a)
# Out:
# 5
# Hello
# 6

# %% [markdown]
# ### method in tuple
# 1. 	len(tuple)
#     Gives the total length of the tuple.
# 2. 	max(tuple)
#     Returns item from the tuple with max value.
# 3. min(tuple)
#    Returns item from the tuple with min value.
# 4. tuple(seq)
#    Converts a list into tuple.

# %%
tup1 = (2,4,3,5,5)
tup2 = (2,4,3,5,5)

print("Max ",max(tup1))
print("Len",len(tup1))
print("Min",min(tup2))
# compare the tuple
print(tup1 == tup2)
# convert tuple into list 
l = list(tup1)
print(type(l))
print(l)
# convert list into tupel
tup1 = tuple(l)
print(type(tup1))
print(tup1)
# Out:
# Max  5
# Len 5
# Min 2
# True
# <class 'list'>
# [2, 4, 3, 5, 5]
# <class 'tuple'>
# (2, 4, 3, 5, 5)
