# %%
import math
math.sqrt(16
)
# Out:
# 4.0

# %%
from math import sqrt,pi

# %%
print(sqrt(4))
print(pi)
# Out:
# 2.0
# 3.141592653589793

# %%
import numpy as np
np.array([1,3,5,5])
# Out:
# array([1, 3, 5, 5])

# %%
## import all module 
from math import *
print(sqrt(16))

print(pi)
# Out:
# 4.0
# 3.141592653589793

# %%
## import own custom package
from package.math import addition
addition(5,6)
# Out:
# 11

# %%
## another way 
from package import math
math.addition(3,5)
# Out:
# 8
