# %% [markdown]
# Polymorphism is an object-oriented programming concept that allows the same function or method name to perform different behaviors depending on the object that calls it.

# %% [markdown]
# ### method overriding
# method overriding allows to child class to provide a specific implementation of a method that is already defined in its parent class

# %%
## base class
class Animal:
    def speak(self):
        return "Sound of the animal"
    
## derived class 1
class Dog(Animal):
    def speak(self):
        return "Woof!"

## Drived class 2 
class Cat(Animal):
    def speak(self):
        return "Meow"
    

## Function that demonstarate the polymorphism
def animal_speak(animal):
    print(animal.speak())
    
dog1 = Dog()
cat = Cat()

print(dog1.speak())
print(cat.speak())
animal_speak(dog1)
# Out:
# Woof!
# Meow
# Woof!

# %%
## polymorphism with function and method
## base class
class Shape:
    def area(self):
        return "Area of the figure"
    
## derived class
class Rectangle(Shape):
    def __init__(self,width,height):
        self.width = width
        self.height = height

    def area(self):
        return self.width * self.height
    
## drived class 2
class Circle(Shape):
    def __init__(self,radius):
        self.radius = radius
    def area(self):
        return 3.14 * self.radius**2
    
## Function that demonstarate the polymorphism
def print_area(shape):
    print(f"the area if {shape.area()}")

## creating the object

rac = Rectangle(4,5)
circle = Circle(3)
print_area(rac)
print_area(circle)
# Out:
# the area if 20
# the area if 28.26

# %% [markdown]
# #### polymorphism with A bstract base class
# Abstract base class (ABCs) are used to define common methods for group of related objects. They can enforce that drived class implement particular method,
# promoting consistancy across different implementions

# %%
from abc import ABC, abstractmethod

## Define a Abstract Class  
class Vihical(ABC):
   @abstractmethod
   def Start_engine(self):
       pass
    
## derived class 1
class Car(Vihical):
    def Start_engine(self):
        return "Car started"
## drived class 2
class MoterCycle(Vihical):
    def Start_engine(self):
        return "MoterCycle Started"
    
## function demonstrates the polymorphism
def start_vihical(vihical):
    print(vihical.Start_engine())
## creating object of car and motercylce

car = Car()
motercycle = MoterCycle()

start_vihical(car)
start_vihical(motercycle)
# Out:
# Car started
# MoterCycle Started
